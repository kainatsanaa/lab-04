# %%
import matplotlib.pyplot as plt
from skimage import io
from skimage.filters.rank import entropy
from skimage.morphology import disk
import numpy as np
from skimage.filters import threshold_otsu
from scipy.stats import linregress
import glob

time = 0
time_list = []
area_list = []

# Update the path and pattern based on your file structure
path ="C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\*.*"

# Print the files returned by glob.glob() for debugging
files = glob.glob(path)
print("Files found:", files)

for file in files:
    img = io.imread(file)
    entropy_img = entropy(img, disk(3))
    thresh = threshold_otsu(entropy_img)
    binary = entropy_img <= thresh
    scratch_area = np.sum(binary == 1)
    print("time=", time, "hr  ", "Scratch area=", scratch_area, "pix²")
    time_list.append(time)
    area_list.append(scratch_area)
    time += 1

plt.plot(time_list, area_list, 'bo')  # Print blue dots scatter plot

slope, intercept, r_value, p_value, std_err = linregress(time_list, area_list)
print("y = ", slope, "x", " + ", intercept)
print("R² = ", r_value**2)
# Out:
# Files found: ['C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\0 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\1 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\12 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\18 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\24 houres.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\3 hours .jpg']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 23
#      21 for file in files:
#      22     img = io.imread(file)
# ---> 23     entropy_img = entropy(img, disk(3))
#      24     thresh = threshold_otsu(entropy_img)
#      25     binary = entropy_img <= thresh
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:1284, in entropy(image, footprint, out, mask, shift_x, shift_y, shift_z)
#    1279     return _apply_scalar_per_pixel(generic_cy._entropy, image, footprint,
#    1280                                    out=out, mask=mask,
#    1281                                    shift_x=shift_x, shift_y=shift_y,
#    1282                                    out_dtype=np.float64)
#    1283 elif np_image.ndim == 3:
# -> 1284     return _apply_scalar_per_pixel_3D(generic_cy._entropy_3D, image,
#    1285                                       footprint, out=out, mask=mask,
#    1286                                       shift_x=shift_x, shift_y=shift_y,
#    1287                                       shift_z=shift_z,
#    1288                                       out_dtype=np.float64)
#    1289 raise ValueError(
#    1290     f'`image` must have 2 or 3 dimensions, got {np_image.ndim}.'
#    1291 )
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:282, in _apply_scalar_per_pixel_3D(func, image, footprint, out, mask, shift_x, shift_y, shift_z, out_dtype)
#     279 def _apply_scalar_per_pixel_3D(func, image, footprint, out, mask, shift_x,
#     280                                shift_y, shift_z, out_dtype=None):
# --> 282     image, footprint, out, mask, n_bins = _handle_input_3D(
#     283         image, footprint, out, mask, out_dtype
#     284     )
#     286     func(image, footprint, shift_x=shift_x, shift_y=shift_y, shift_z=shift_z,
#     287          mask=mask, out=out, n_bins=n_bins)
#     289     return out.reshape(out.shape[:3])
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:204, in _handle_input_3D(image, footprint, out, mask, out_dtype, pixel_size)
#     202 footprint = np.ascontiguousarray(img_as_ubyte(footprint > 0))
#     203 if footprint.ndim != image.ndim:
# --> 204     raise ValueError('Image dimensions and neighborhood dimensions'
#     205                      'do not match')
#     206 image = np.ascontiguousarray(image)
#     208 if mask is None:
#
# ValueError: Image dimensions and neighborhood dimensionsdo not match

# %%
import matplotlib.pyplot as plt
from skimage import io
from skimage.filters.rank import entropy
from skimage.morphology import disk
import numpy as np
from skimage.filters import threshold_otsu
from scipy.stats import linregress
import glob

time = 0
time_list = []
area_list = []

# Update the path and pattern based on your file structure
path = "C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\*.*"

# Print the files returned by glob.glob() for debugging
files = glob.glob(path)
print("Files found:", files)

for file in files:
    img = io.imread(file)
    entropy_img = entropy(img, disk(3))
    thresh = threshold_otsu(entropy_img)
    binary = entropy_img <= thresh
    scratch_area = np.sum(binary == 1)
    print("time=", time, "hr  ", "Scratch area=", scratch_area, "pix²")
    time_list.append(time)
    area_list.append(scratch_area)
    time += 1

plt.plot(time_list, area_list, 'bo')  # Print blue dots scatter plot

slope, intercept, r_value, p_value, std_err = linregress(time_list, area_list)
print("y = ", slope, "x", " + ", intercept)
print("R² = ", r_value**2)
# Out:
# Files found: ['C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\0 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\1 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\12 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\18 hours.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\24 houres.jpg', 'C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\3 hours .jpg']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 23
#      21 for file in files:
#      22     img = io.imread(file)
# ---> 23     entropy_img = entropy(img, disk(3))
#      24     thresh = threshold_otsu(entropy_img)
#      25     binary = entropy_img <= thresh
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:1284, in entropy(image, footprint, out, mask, shift_x, shift_y, shift_z)
#    1279     return _apply_scalar_per_pixel(generic_cy._entropy, image, footprint,
#    1280                                    out=out, mask=mask,
#    1281                                    shift_x=shift_x, shift_y=shift_y,
#    1282                                    out_dtype=np.float64)
#    1283 elif np_image.ndim == 3:
# -> 1284     return _apply_scalar_per_pixel_3D(generic_cy._entropy_3D, image,
#    1285                                       footprint, out=out, mask=mask,
#    1286                                       shift_x=shift_x, shift_y=shift_y,
#    1287                                       shift_z=shift_z,
#    1288                                       out_dtype=np.float64)
#    1289 raise ValueError(
#    1290     f'`image` must have 2 or 3 dimensions, got {np_image.ndim}.'
#    1291 )
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:282, in _apply_scalar_per_pixel_3D(func, image, footprint, out, mask, shift_x, shift_y, shift_z, out_dtype)
#     279 def _apply_scalar_per_pixel_3D(func, image, footprint, out, mask, shift_x,
#     280                                shift_y, shift_z, out_dtype=None):
# --> 282     image, footprint, out, mask, n_bins = _handle_input_3D(
#     283         image, footprint, out, mask, out_dtype
#     284     )
#     286     func(image, footprint, shift_x=shift_x, shift_y=shift_y, shift_z=shift_z,
#     287          mask=mask, out=out, n_bins=n_bins)
#     289     return out.reshape(out.shape[:3])
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:204, in _handle_input_3D(image, footprint, out, mask, out_dtype, pixel_size)
#     202 footprint = np.ascontiguousarray(img_as_ubyte(footprint > 0))
#     203 if footprint.ndim != image.ndim:
# --> 204     raise ValueError('Image dimensions and neighborhood dimensions'
#     205                      'do not match')
#     206 image = np.ascontiguousarray(image)
#     208 if mask is None:
#
# ValueError: Image dimensions and neighborhood dimensionsdo not match

# %%
import matplotlib.pyplot as plt
from skimage import io, color, transform, util
from skimage.filters.rank import entropy
from skimage.morphology import disk
import numpy as np
from skimage.filters import threshold_otsu
from scipy.stats import linregress
import glob

time = 0
time_list = []
area_list = []

# Update the path and pattern based on your file structure
path = r"C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\*.*"

# Print the files returned by glob.glob() for debugging
files = glob.glob(path)
print("Files found:", files)

for file in files:
    img = io.imread(file)

    # Convert the image to grayscale if it's not already
    if img.ndim == 3:
        img = color.rgb2gray(img)

    # Resize the image to a consistent size
    target_size = (256, 256)  # Adjust the target size as needed
    img = transform.resize(img, target_size, anti_aliasing=True)

    # Convert the image to uint8 to silence the warning
    img = util.img_as_ubyte(img)

    entropy_img = entropy(img, disk(3))
    thresh = threshold_otsu(entropy_img)
    binary = entropy_img <= thresh
    scratch_area = np.sum(binary == 1)
    print("time=", time, "hr  ", "Scratch area=", scratch_area, "pix²")
    time_list.append(time)
    area_list.append(scratch_area)
    time += 1

plt.plot(time_list, area_list, 'bo')  # Print blue dots scatter plot

slope, intercept, r_value, p_value, std_err = linregress(time_list, area_list)
print("y = ", slope, "x", " + ", intercept)
print("R² = ", r_value**2)

# Display the scatter plot
plt.show()
# Out:
# Files found: ['C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\0 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\1 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\12 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\18 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\24 houres.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\3 hours .jpg']
# time= 0 hr   Scratch area= 38784 pix²
# time= 1 hr   Scratch area= 37291 pix²
# time= 2 hr   Scratch area= 27452 pix²
# time= 3 hr   Scratch area= 23803 pix²
# time= 4 hr   Scratch area= 19872 pix²
# time= 5 hr   Scratch area= 33257 pix²
# y =  -2386.8857142857146 x  +  36043.71428571429
# R² =  0.34575113719633155

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap='gray')
plt.title('Original Image')

plt.subplot(1, 2, 2)
plt.imshow(binary, cmap='gray')
plt.title('Thresholded Image')

plt.show()

# %%
import matplotlib.pyplot as plt
from skimage import io
from skimage.filters.rank import entropy
from skimage.morphology import disk
import numpy as np
from skimage.filters import threshold_otsu
from scipy.stats import linregress
import glob

time = 0
time_list = []
area_list = []

# Update the path and pattern based on your file structure
path = r"C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\*.*"

# Print the files returned by glob.glob() for debugging
files = glob.glob(path)
print("Files found:", files)

num_images = len(files)

# Define the number of rows and columns for the subplot grid
num_rows = 2
num_cols = num_images // num_rows

# Create a figure and a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

for idx, file in enumerate(files):
    img = io.imread(file)
    entropy_img = entropy(img, disk(3))
    thresh = threshold_otsu(entropy_img)
    binary = entropy_img <= thresh
    scratch_area = np.sum(binary == 1)
    print("time=", time, "hr  ", "Scratch area=", scratch_area, "pix²")
    time_list.append(time)
    area_list.append(scratch_area)
    time += 1

    # Calculate the subplot index
    row_idx = idx // num_cols
    col_idx = idx % num_cols

    # Display the original image and the thresholded image in the subplot
    axes[row_idx, col_idx].imshow(img, cmap='gray')
    axes[row_idx, col_idx].set_title(f'Time = {time} hr\nArea = {scratch_area} pix²')

# Adjust layout and display the figure
plt.tight_layout()
plt.show()

plt.plot(time_list, area_list, 'bo')  # Print blue dots scatter plot

slope, intercept, r_value, p_value, std_err = linregress(time_list, area_list)
print("y = ", slope, "x", " + ", intercept)
print("R² = ", r_value**2)
# Out:
# Files found: ['C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\0 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\1 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\12 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\18 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\24 houres.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\3 hours .jpg']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 32
#      30 for idx, file in enumerate(files):
#      31     img = io.imread(file)
# ---> 32     entropy_img = entropy(img, disk(3))
#      33     thresh = threshold_otsu(entropy_img)
#      34     binary = entropy_img <= thresh
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:1284, in entropy(image, footprint, out, mask, shift_x, shift_y, shift_z)
#    1279     return _apply_scalar_per_pixel(generic_cy._entropy, image, footprint,
#    1280                                    out=out, mask=mask,
#    1281                                    shift_x=shift_x, shift_y=shift_y,
#    1282                                    out_dtype=np.float64)
#    1283 elif np_image.ndim == 3:
# -> 1284     return _apply_scalar_per_pixel_3D(generic_cy._entropy_3D, image,
#    1285                                       footprint, out=out, mask=mask,
#    1286                                       shift_x=shift_x, shift_y=shift_y,
#    1287                                       shift_z=shift_z,
#    1288                                       out_dtype=np.float64)
#    1289 raise ValueError(
#    1290     f'`image` must have 2 or 3 dimensions, got {np_image.ndim}.'
#    1291 )
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:282, in _apply_scalar_per_pixel_3D(func, image, footprint, out, mask, shift_x, shift_y, shift_z, out_dtype)
#     279 def _apply_scalar_per_pixel_3D(func, image, footprint, out, mask, shift_x,
#     280                                shift_y, shift_z, out_dtype=None):
# --> 282     image, footprint, out, mask, n_bins = _handle_input_3D(
#     283         image, footprint, out, mask, out_dtype
#     284     )
#     286     func(image, footprint, shift_x=shift_x, shift_y=shift_y, shift_z=shift_z,
#     287          mask=mask, out=out, n_bins=n_bins)
#     289     return out.reshape(out.shape[:3])
#
# File ~\anaconda3\Lib\site-packages\skimage\filters\rank\generic.py:204, in _handle_input_3D(image, footprint, out, mask, out_dtype, pixel_size)
#     202 footprint = np.ascontiguousarray(img_as_ubyte(footprint > 0))
#     203 if footprint.ndim != image.ndim:
# --> 204     raise ValueError('Image dimensions and neighborhood dimensions'
#     205                      'do not match')
#     206 image = np.ascontiguousarray(image)
#     208 if mask is None:
#
# ValueError: Image dimensions and neighborhood dimensionsdo not match

# %%
import matplotlib.pyplot as plt
from skimage import io, color
from skimage.filters.rank import entropy
from skimage.morphology import disk
import numpy as np
from skimage.filters import threshold_otsu
from scipy.stats import linregress
import glob

time = 0
time_list = []
area_list = []

# Update the path and pattern based on your file structure
path = r"C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\*.*"
# Print the files returned by glob.glob() for debugging
files = glob.glob(path)
print("Files found:", files)

num_images = len(files)

# Calculate the number of rows and columns needed for the subplot grid
num_cols = 3
num_rows = (num_images + num_cols - 1) // num_cols

# Create a figure and a grid of subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

for idx, file in enumerate(files):
    img = io.imread(file)

    # Convert to grayscale if the image is not already in grayscale
    if img.ndim == 3:
        img = color.rgb2gray(img)

    entropy_img = entropy(img, disk(3))
    thresh = threshold_otsu(entropy_img)
    binary = entropy_img <= thresh
    scratch_area = np.sum(binary == 1)
    print("time=", time, "hr  ", "Scratch area=", scratch_area, "pix²")
    time_list.append(time)
    area_list.append(scratch_area)
    time += 1

    # Calculate the subplot index
    row_idx = idx // num_cols
    col_idx = idx % num_cols

    # Display the original image and the thresholded image in the subplot
    axes[row_idx, col_idx].imshow(img, cmap='gray')
    axes[row_idx, col_idx].set_title(f'Time = {time} hr\nArea = {scratch_area} pix²')

# Adjust layout and display the figure
plt.tight_layout()
plt.show()

plt.plot(time_list, area_list, 'bo')  # Print blue dots scatter plot

slope, intercept, r_value, p_value, std_err = linregress(time_list, area_list)
print("y = ", slope, "x", " + ", intercept)
print("R² = ", r_value**2)
# Out:
# Files found: ['C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\0 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\1 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\12 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\18 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\24 houres.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\3 hours .jpg']
# time= 0 hr   Scratch area= 11573 pix²
# time= 1 hr   Scratch area= 11644 pix²
# C:\Users\Faizan Hameed\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3526: UserWarning: Possible precision loss converting image of type float64 to uint8 as required by rank filters. Convert manually using skimage.util.img_as_ubyte to silence this warning.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# time= 2 hr   Scratch area= 8599 pix²
# time= 3 hr   Scratch area= 7723 pix²
# time= 4 hr   Scratch area= 6805 pix²
# time= 5 hr   Scratch area= 10926 pix²
# y =  -532.2285714285714 x  +  10875.571428571428
# R² =  0.223821067393144

# %%
import matplotlib.pyplot as plt
from skimage import io, color
from skimage.filters.rank import entropy
from skimage.morphology import disk
import numpy as np
from skimage.filters import threshold_otsu
from scipy.stats import linregress
import glob

time = 0
time_list = []
area_list = []

# Update the path and pattern based on your file structure
path = r"C:\\Users\\Faizan Hameed\\OneDrive\\Documents\\Scratch Assay\\*.*"
# Print the files returned by glob.glob() for debugging
files = glob.glob(path)
print("Files found:", files)

num_images = len(files)

# Create a figure and a grid of subplots
fig, axes = plt.subplots(num_images, 2, figsize=(10, num_images * 5))

for idx, file in enumerate(files):
    img = io.imread(file)
    
    # Convert the image to grayscale
    gray_img = color.rgb2gray(img)
    
    entropy_img = entropy(gray_img, disk(3))
    thresh = threshold_otsu(entropy_img)
    binary = entropy_img <= thresh
    scratch_area = np.sum(binary == 1)
    print("time=", time, "hr  ", "Scratch area=", scratch_area, "pix²")
    time_list.append(time)
    area_list.append(scratch_area)
    time += 1

    # Display the original image in the left column
    axes[idx, 0].imshow(img, cmap='gray')
    axes[idx, 0].set_title(f'Time = {time} hr\nOriginal Image')

    # Display the thresholded image in the right column with a binary colormap
    axes[idx, 1].imshow(binary, cmap='coolwarm', interpolation='none')
    axes[idx, 1].set_title('Thresholded Image')

# Adjust layout and display the figure
plt.tight_layout()
plt.show()

plt.plot(time_list, area_list, 'bo')  # Print blue dots scatter plot

slope, intercept, r_value, p_value, std_err = linregress(time_list, area_list)
print("y = ", slope, "x", " + ", intercept)
print("R² = ", r_value**2)
# Out:
# Files found: ['C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\0 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\1 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\12 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\18 hours.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\24 houres.jpg', 'C:\\\\Users\\\\Faizan Hameed\\\\OneDrive\\\\Documents\\\\Scratch Assay\\3 hours .jpg']
# time= 0 hr   Scratch area= 11573 pix²
# time= 1 hr   Scratch area= 11644 pix²
# time= 2 hr   Scratch area= 8599 pix²
# time= 3 hr   Scratch area= 7723 pix²
# time= 4 hr   Scratch area= 6805 pix²
# time= 5 hr   Scratch area= 10926 pix²
# y =  -532.2285714285714 x  +  10875.571428571428
# R² =  0.223821067393144
